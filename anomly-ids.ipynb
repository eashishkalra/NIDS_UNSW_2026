# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('./dataset/cicids2017c'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# ./dataset/cicids2017c\cicids2017_cleaned.csv

# %%
df=pd.read_csv('./dataset/cicids2017c/cicids2017_cleaned.csv')

# %%
df.columns
# Out:
# Index(['Destination Port', 'Flow Duration', 'Total Fwd Packets',
#        'Total Length of Fwd Packets', 'Fwd Packet Length Max',
#        'Fwd Packet Length Min', 'Fwd Packet Length Mean',
#        'Fwd Packet Length Std', 'Bwd Packet Length Max',
#        'Bwd Packet Length Min', 'Bwd Packet Length Mean',
#        'Bwd Packet Length Std', 'Flow Bytes/s', 'Flow Packets/s',
#        'Flow IAT Mean', 'Flow IAT Std', 'Flow IAT Max', 'Flow IAT Min',
#        'Fwd IAT Total', 'Fwd IAT Mean', 'Fwd IAT Std', 'Fwd IAT Max',
#        'Fwd IAT Min', 'Bwd IAT Total', 'Bwd IAT Mean', 'Bwd IAT Std',
#        'Bwd IAT Max', 'Bwd IAT Min', 'Fwd Header Length', 'Bwd Header Length',
#        'Fwd Packets/s', 'Bwd Packets/s', 'Min Packet Length',
#        'Max Packet Length', 'Packet Length Mean', 'Packet Length Std',
#        'Packet Length Variance', 'FIN Flag Count', 'PSH Flag Count',
#        'ACK Flag Count', 'Average Packet Size', 'Subflow Fwd Bytes',
#        'Init_Win_bytes_forward', 'Init_Win_bytes_backward', 'act_data_pkt_fwd',
#        'min_seg_size_forward', 'Active Mean', 'Active Max', 'Active Min',
#        'Idle Mean', 'Idle Max', 'Idle Min', 'Attack Type'],
#       dtype='object')

# %%
df.head()
# Out:
#    Destination Port  Flow Duration  Total Fwd Packets  \
# 0                22        1266342                 41
# 1                22        1319353                 41
# 2                22            160                  1
# 3                22        1303488                 41
# 4             35396             77                  1
#
#    Total Length of Fwd Packets  Fwd Packet Length Max  Fwd Packet Length Min  \
# 0                         2664                    456                      0
# 1                         2664                    456                      0
# 2                            0                      0                      0
# 3                         2728                    456                      0
# 4                            0                      0                      0
#
#    Fwd Packet Length Mean  Fwd Packet Length Std  Bwd Packet Length Max  \
# 0               64.975610             109.864573                    976
# 1               64.975610             109.864573                    976
# 2                0.000000               0.000000                      0
# 3               66.536585             110.129945                    976
# 4                0.000000               0.000000                      0
#
#    Bwd Packet Length Min  ...  Init_Win_bytes_backward  act_data_pkt_fwd  \
# 0                      0  ...                      243                24
# 1                      0  ...                      243                24
# 2                      0  ...                      243                 0
# 3                      0  ...                      243                24
# 4                      0  ...                      290                 0
#
#    min_seg_size_forward  Active Mean  Active Max  Active Min  Idle Mean  \
# 0                    32          0.0           0           0        0.0
# 1                    32          0.0           0           0        0.0
# 2                    32          0.0           0           0        0.0
# 3                    32          0.0           0           0        0.0
# 4                    32          0.0           0           0        0.0
#
#    Idle Max  Idle Min     Attack Type
# 0         0         0  Normal Traffic
# 1         0         0  Normal Traffic
# 2         0         0  Normal Traffic
# 3         0         0  Normal Traffic
# 4         0         0  Normal Traffic
#
# [5 rows x 53 columns]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import (
    classification_report, confusion_matrix,
    roc_auc_score, roc_curve, f1_score, accuracy_score
)
from sklearn.feature_selection import VarianceThreshold
from sklearn.utils.class_weight import compute_class_weight
from imblearn.over_sampling import SMOTE

import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import (
    GRU, Dense, Dropout, BatchNormalization,
    Bidirectional, Input, Masking
)
from tensorflow.keras.callbacks import (
    EarlyStopping, ReduceLROnPlateau,
    ModelCheckpoint, TensorBoard
)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2

# Set seeds for reproducibility
SEED = 42
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %%
df.shape
# Out:
# (2520751, 53)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2520751 entries, 0 to 2520750
# Data columns (total 53 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   Destination Port             int64
#  1   Flow Duration                int64
#  2   Total Fwd Packets            int64
#  3   Total Length of Fwd Packets  int64
#  4   Fwd Packet Length Max        int64
#  5   Fwd Packet Length Min        int64
#  6   Fwd Packet Length Mean       float64
#  7   Fwd Packet Length Std        float64
#  8   Bwd Packet Length Max        int64
#  9   Bwd Packet Length Min        int64
#  10  Bwd Packet Length Mean       float64
#  11  Bwd Packet Length Std        float64
#  12  Flow Bytes/s                 float64
#  13  Flow Packets/s               float64
#  14  Flow IAT Mean                float64
#  15  Flow IAT Std                 float64
#  16  Flow IAT Max                 int64
#  17  Flow IAT Min                 int64
#  18  Fwd IAT Total                int64
#  19  Fwd IAT Mean                 float64
#  20  Fwd IAT Std                  float64
#  21  Fwd IAT Max                  int64
#  22  Fwd IAT Min                  int64
#  23  Bwd IAT Total                int64
#  24  Bwd IAT Mean                 float64
#  25  Bwd IAT Std                  float64
#  26  Bwd IAT Max                  int64
#  27  Bwd IAT Min                  int64
#  28  Fwd Header Length            int64
#  29  Bwd Header Length            int64
#  30  Fwd Packets/s                float64
#  31  Bwd Packets/s                float64
#  32  Min Packet Length            int64
#  33  Max Packet Length            int64
#  34  Packet Length Mean           float64
#  35  Packet Length Std            float64
#  36  Packet Length Variance       float64
#  37  FIN Flag Count               int64
#  38  PSH Flag Count               int64
#  39  ACK Flag Count               int64
#  40  Average Packet Size          float64
#  41  Subflow Fwd Bytes            int64
#  42  Init_Win_bytes_forward       int64
#  43  Init_Win_bytes_backward      int64
#  44  act_data_pkt_fwd             int64
#  45  min_seg_size_forward         int64
#  46  Active Mean                  float64
#  47  Active Max                   int64
#  48  Active Min                   int64
#  49  Idle Mean                    float64
#  50  Idle Max                     int64
#  51  Idle Min                     int64
#  52  Attack Type                  object
# dtypes: float64(20), int64(32), object(1)
# memory usage: 1019.3+ MB

# %%
df.describe()
# Out:
#        Destination Port  Flow Duration  Total Fwd Packets  \
# count      2.520751e+06   2.520751e+06       2.520751e+06
# mean       8.690744e+03   1.659032e+07       1.025880e+01
# std        1.901294e+04   3.523140e+07       7.943824e+02
# min        0.000000e+00  -1.300000e+01       1.000000e+00
# 25%        5.300000e+01   2.080000e+02       2.000000e+00
# 50%        8.000000e+01   5.062000e+04       2.000000e+00
# 75%        4.430000e+02   5.332968e+06       6.000000e+00
# max        6.553500e+04   1.200000e+08       2.197590e+05
#
#        Total Length of Fwd Packets  Fwd Packet Length Max  \
# count                 2.520751e+06           2.520751e+06
# mean                  6.065243e+02           2.311993e+02
# std                   1.011595e+04           7.563122e+02
# min                   0.000000e+00           0.000000e+00
# 25%                   1.200000e+01           6.000000e+00
# 50%                   6.600000e+01           4.000000e+01
# 75%                   3.320000e+02           2.020000e+02
# max                   1.290000e+07           2.482000e+04
#
#        Fwd Packet Length Min  Fwd Packet Length Mean  Fwd Packet Length Std  \
# count           2.520751e+06            2.520751e+06           2.520751e+06
# mean            1.920377e+01            6.350189e+01           7.732029e+01
# std             6.079887e+01            1.955512e+02           2.968824e+02
# min             0.000000e+00            0.000000e+00           0.000000e+00
# 25%             0.000000e+00            6.000000e+00           0.000000e+00
# 50%             2.000000e+00            3.625000e+01           0.000000e+00
# 75%             3.700000e+01            5.200000e+01           7.419280e+01
# max             2.325000e+03            5.940857e+03           7.125597e+03
#
#        Bwd Packet Length Max  Bwd Packet Length Min  ...  \
# count           2.520751e+06           2.520751e+06  ...
# mean            9.749253e+02           4.316019e+01  ...
# std             2.038152e+03           7.088017e+01  ...
# min             0.000000e+00           0.000000e+00  ...
# 25%             6.000000e+00           0.000000e+00  ...
# 50%             9.700000e+01           0.000000e+00  ...
# 75%             7.460000e+02           8.200000e+01  ...
# max             1.953000e+04           2.896000e+03  ...
#
#        Init_Win_bytes_forward  Init_Win_bytes_backward  act_data_pkt_fwd  \
# count            2.520751e+06             2.520751e+06      2.520751e+06
# mean             7.265707e+03             2.228741e+03      5.997266e+00
# std              1.459805e+04             8.924482e+03      6.743909e+02
# min             -1.000000e+00            -1.000000e+00      0.000000e+00
# 25%             -1.000000e+00            -1.000000e+00      0.000000e+00
# 50%              2.510000e+02             0.000000e+00      1.000000e+00
# 75%              8.192000e+03             2.350000e+02      3.000000e+00
# max              6.553500e+04             6.553500e+04      2.135570e+05
#
#        min_seg_size_forward   Active Mean    Active Max    Active Min  \
# count          2.520751e+06  2.520751e+06  2.520751e+06  2.520751e+06
# mean          -3.082291e+03  9.152230e+04  1.719410e+05  6.542438e+04
# std            1.149769e+06  6.858746e+05  1.084664e+06  6.106447e+05
# min           -5.368707e+08  0.000000e+00  0.000000e+00  0.000000e+00
# 25%            2.000000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 50%            2.000000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 75%            3.200000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# max            1.380000e+02  1.100000e+08  1.100000e+08  1.100000e+08
#
#           Idle Mean      Idle Max      Idle Min
# count  2.520751e+06  2.520751e+06  2.520751e+06
# mean   9.337159e+06  9.763454e+06  8.892545e+06
# std    2.484810e+07  2.561725e+07  2.458139e+07
# min    0.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00
# 50%    0.000000e+00  0.000000e+00  0.000000e+00
# 75%    0.000000e+00  0.000000e+00  0.000000e+00
# max    1.200000e+08  1.200000e+08  1.200000e+08
#
# [8 rows x 52 columns]

# %%
df['Attack Type'].value_counts()
# Out:
# Attack Type
# Normal Traffic    2095057
# DoS                193745
# DDoS               128014
# Port Scanning       90694
# Brute Force          9150
# Web Attacks          2143
# Bots                 1948
# Name: count, dtype: int64

# %%
numeric_df = df.select_dtypes(include=[np.number])
print('=== Data Quality ===')
print(f'Rows          : {len(df):,}')
print(f'Columns       : {len(df.columns)}')
print(f'NaN values    : {df.isnull().sum().sum():,}')
print(f'Inf values    : {np.isinf(numeric_df).sum().sum():,}')
print(f'Duplicates    : {df.duplicated().sum():,}')
print(f'Numeric cols  : {len(numeric_df.columns)}')
print(f'\nValue range   : [{numeric_df.min().min():.4f}, {numeric_df.max().max():.4f}]')
# Out:
# === Data Quality ===
# Rows          : 2,520,751
# Columns       : 53
# NaN values    : 0
# Inf values    : 0
# Duplicates    : 161
# Numeric cols  : 52
#
# Value range   : [-32212234632.0000, 2071000000.0000]

# %%
df.duplicated().sum()
# Out:
# np.int64(161)

# %%
df= df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (2520590, 53)

# %%
LABEL_COL  = 'Attack Type'      # exact column name
BENIGN_STR = 'Normal Traffic'   # exact benign label

print(f'Using label column : {LABEL_COL}')
print(f'Benign label value : {BENIGN_STR}')
print(f'\nClass distribution:')
print(df[LABEL_COL].value_counts().to_string())
# Out:
# Using label column : Attack Type
# Benign label value : Normal Traffic
#
# Class distribution:
# Attack Type
# Normal Traffic    2094896
# DoS                193745
# DDoS               128014
# Port Scanning       90694
# Brute Force          9150
# Web Attacks          2143
# Bots                 1948

# %%
# ── Quick data quality check ──────────────────────────────────────────────────
numeric_df = df.select_dtypes(include=[np.number])
print('=== Data Quality ===')
print(f'Rows          : {len(df):,}')
print(f'Columns       : {len(df.columns)}')
print(f'NaN values    : {df.isnull().sum().sum():,}')
print(f'Inf values    : {np.isinf(numeric_df).sum().sum():,}')
print(f'Duplicates    : {df.duplicated().sum():,}')
print(f'Numeric cols  : {len(numeric_df.columns)}')
print(f'\nValue range   : [{numeric_df.min().min():.4f}, {numeric_df.max().max():.4f}]')
# Out:
# === Data Quality ===
# Rows          : 2,520,590
# Columns       : 53
# NaN values    : 0
# Inf values    : 0
# Duplicates    : 0
# Numeric cols  : 52
#
# Value range   : [-32212234632.0000, 2071000000.0000]

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 4))
fig.suptitle('CICIDS2017 — Class Distribution', fontsize=13, fontweight='bold')

# All attack types
counts = df[LABEL_COL].value_counts()
counts.plot(kind='bar', ax=axes[0], color='steelblue', edgecolor='black', width=0.7)
axes[0].set_title('All Categories')
axes[0].set_xlabel('Label'); axes[0].set_ylabel('Count')
axes[0].tick_params(axis='x', rotation=45)
axes[0].grid(axis='y', alpha=0.3)

# Binary
is_benign   = df[LABEL_COL].astype(str).str.strip() == BENIGN_STR
binary_cnts = pd.Series({'Normal Traffic (0)': is_benign.sum(), 'Attack (1)': (~is_benign).sum()})
binary_cnts.plot(kind='bar', ax=axes[1], color=['#4CAF50','#F44336'], edgecolor='black', width=0.5)
axes[1].set_title('Binary: Normal Traffic vs Attack')
axes[1].set_ylabel('Count')
axes[1].tick_params(axis='x', rotation=0)
axes[1].grid(axis='y', alpha=0.3)

# %%
# 3.1 — Binary label encoding
df['binary_label'] = df[LABEL_COL].apply(
    lambda x: 0 if str(x).strip() == BENIGN_STR else 1
)
y = df['binary_label'].values

print('Binary label distribution:')
print(f'  Normal Traffic (0) : {(y==0).sum():>10,}  ({(y==0).mean()*100:.1f}%)')
print(f'  Attack         (1) : {(y==1).sum():>10,}  ({(y==1).mean()*100:.1f}%)')
print(f'  Imbalance ratio    :  1 : {(y==1).sum()/max((y==0).sum(),1):.2f}')
# Out:
# Binary label distribution:
#   Normal Traffic (0) :  2,094,896  (83.1%)
#   Attack         (1) :    425,694  (16.9%)
#   Imbalance ratio    :  1 : 0.20

# %%
# 3.2 — Build feature matrix
DROP = [LABEL_COL, 'binary_label',
        'Flow ID', 'Source IP', 'Destination IP', 'Timestamp',
        'Src IP', 'Dst IP', 'src_ip', 'dst_ip', 'flow_id']
DROP = [c for c in DROP if c in df.columns]

X = df.drop(columns=DROP).select_dtypes(include=[np.number])
print(f'Feature matrix: {X.shape[0]:,} rows × {X.shape[1]} features')
# Out:
# Feature matrix: 2,520,590 rows × 52 features

# %%
df.columns
# Out:
# Index(['Destination Port', 'Flow Duration', 'Total Fwd Packets',
#        'Total Length of Fwd Packets', 'Fwd Packet Length Max',
#        'Fwd Packet Length Min', 'Fwd Packet Length Mean',
#        'Fwd Packet Length Std', 'Bwd Packet Length Max',
#        'Bwd Packet Length Min', 'Bwd Packet Length Mean',
#        'Bwd Packet Length Std', 'Flow Bytes/s', 'Flow Packets/s',
#        'Flow IAT Mean', 'Flow IAT Std', 'Flow IAT Max', 'Flow IAT Min',
#        'Fwd IAT Total', 'Fwd IAT Mean', 'Fwd IAT Std', 'Fwd IAT Max',
#        'Fwd IAT Min', 'Bwd IAT Total', 'Bwd IAT Mean', 'Bwd IAT Std',
#        'Bwd IAT Max', 'Bwd IAT Min', 'Fwd Header Length', 'Bwd Header Length',
#        'Fwd Packets/s', 'Bwd Packets/s', 'Min Packet Length',
#        'Max Packet Length', 'Packet Length Mean', 'Packet Length Std',
#        'Packet Length Variance', 'FIN Flag Count', 'PSH Flag Count',
#        'ACK Flag Count', 'Average Packet Size', 'Subflow Fwd Bytes',
#        'Init_Win_bytes_forward', 'Init_Win_bytes_backward', 'act_data_pkt_fwd',
#        'min_seg_size_forward', 'Active Mean', 'Active Max', 'Active Min',
#        'Idle Mean', 'Idle Max', 'Idle Min', 'Attack Type', 'binary_label'],
#       dtype='object')

# %%
# 3.3 — Safety cleanup (handles any leftover inf/nan)
X = X.replace([np.inf, -np.inf], np.nan)
X = X.fillna(X.median(numeric_only=True))
print(f'After cleanup — NaN: {X.isnull().sum().sum()} | Inf: {np.isinf(X).sum().sum()}')
# Out:
# After cleanup — NaN: 0 | Inf: 0

# %%
# 3.4 — Remove near-zero variance features
vt = VarianceThreshold(threshold=1e-4)
X_vt = vt.fit_transform(X)
SELECTED_FEATURES = X.columns[vt.get_support()].tolist()
X = pd.DataFrame(X_vt, columns=SELECTED_FEATURES)
NUM_FEATURES = X.shape[1]
print(f'Features kept : {NUM_FEATURES}  (removed {len(vt.get_support()) - NUM_FEATURES} low-variance)')
# Out:
# Features kept : 52  (removed 0 low-variance)

# %%
# 3.5 — Split FIRST: Train / Val / Test  (70 / 15 / 15, stratified)
# ✅ We split BEFORE scaling — scaler must never see val/test data
X_arr = X.values
y_type = df[LABEL_COL].astype(str).values

X_tmp, X_test, y_tmp, y_test, y_type_tmp, y_type_test = train_test_split(
    X_arr, y, y_type, test_size=0.15, random_state=SEED, stratify=y
)
X_train, X_val, y_train, y_val, y_type_train, y_type_val = train_test_split(
    X_tmp, y_tmp, y_type_tmp, test_size=0.176, random_state=SEED, stratify=y_tmp
)

print(f'Train : {X_train.shape}   Normal:{(y_train==0).sum():,}  Attack:{(y_train==1).sum():,}')
print(f'Val   : {X_val.shape}     Normal:{(y_val==0).sum():,}    Attack:{(y_val==1).sum():,}')
print(f'Test  : {X_test.shape}    Normal:{(y_test==0).sum():,}   Attack:{(y_test==1).sum():,}')
# Out:
# Train : (1765420, 52)   Normal:1,467,264  Attack:298,156
# Val   : (377081, 52)     Normal:313,397    Attack:63,684
# Test  : (378089, 52)    Normal:314,235   Attack:63,854

# %%
# 3.6 — StandardScaler: fit on TRAIN only, transform all three
# ✅ Prevents data leakage — val/test statistics never influence the scaler
scaler  = StandardScaler()
X_train = scaler.fit_transform(X_train)   # learns mean & std from train only
X_val   = scaler.transform(X_val)         # applies train's mean & std
X_test  = scaler.transform(X_test)        # applies train's mean & std
print(f'Scaled — Train mean≈{X_train.mean():.4f} | std≈{X_train.std():.4f}')
# Out:
# Scaled — Train mean≈0.0000 | std≈1.0000

# %%
df.describe()
# Out:
#        Destination Port  Flow Duration  Total Fwd Packets  \
# count      2.520590e+06   2.520590e+06       2.520590e+06
# mean       8.689420e+03   1.659138e+07       1.025937e+01
# std        1.901153e+04   3.523228e+07       7.944078e+02
# min        0.000000e+00  -1.300000e+01       1.000000e+00
# 25%        5.300000e+01   2.080000e+02       2.000000e+00
# 50%        8.000000e+01   5.062500e+04       2.000000e+00
# 75%        4.430000e+02   5.333478e+06       6.000000e+00
# max        6.553500e+04   1.200000e+08       2.197590e+05
#
#        Total Length of Fwd Packets  Fwd Packet Length Max  \
# count                 2.520590e+06           2.520590e+06
# mean                  6.065630e+02           2.312140e+02
# std                   1.011627e+04           7.563342e+02
# min                   0.000000e+00           0.000000e+00
# 25%                   1.200000e+01           6.000000e+00
# 50%                   6.600000e+01           4.000000e+01
# 75%                   3.320000e+02           2.020000e+02
# max                   1.290000e+07           2.482000e+04
#
#        Fwd Packet Length Min  Fwd Packet Length Mean  Fwd Packet Length Std  \
# count           2.520590e+06            2.520590e+06           2.520590e+06
# mean            1.920495e+01            6.350589e+01           7.732523e+01
# std             6.080063e+01            1.955568e+02           2.968912e+02
# min             0.000000e+00            0.000000e+00           0.000000e+00
# 25%             0.000000e+00            6.000000e+00           0.000000e+00
# 50%             2.000000e+00            3.625000e+01           0.000000e+00
# 75%             3.700000e+01            5.200000e+01           7.419280e+01
# max             2.325000e+03            5.940857e+03           7.125597e+03
#
#        Bwd Packet Length Max  Bwd Packet Length Min  ...  \
# count           2.520590e+06           2.520590e+06  ...
# mean            9.749875e+02           4.316292e+01  ...
# std             2.038203e+03           7.088161e+01  ...
# min             0.000000e+00           0.000000e+00  ...
# 25%             6.000000e+00           0.000000e+00  ...
# 50%             9.800000e+01           0.000000e+00  ...
# 75%             7.460000e+02           8.200000e+01  ...
# max             1.953000e+04           2.896000e+03  ...
#
#        Init_Win_bytes_backward  act_data_pkt_fwd  min_seg_size_forward  \
# count             2.520590e+06      2.520590e+06          2.520590e+06
# mean              2.227698e+03      5.997646e+00         -3.082490e+03
# std               8.922472e+03      6.744124e+02          1.149806e+06
# min              -1.000000e+00      0.000000e+00         -5.368707e+08
# 25%              -1.000000e+00      0.000000e+00          2.000000e+01
# 50%               0.000000e+00      1.000000e+00          2.000000e+01
# 75%               2.350000e+02      3.000000e+00          3.200000e+01
# max               6.553500e+04      2.135570e+05          1.380000e+02
#
#         Active Mean    Active Max    Active Min     Idle Mean      Idle Max  \
# count  2.520590e+06  2.520590e+06  2.520590e+06  2.520590e+06  2.520590e+06
# mean   9.152814e+04  1.719520e+05  6.542856e+04  9.337756e+06  9.764078e+06
# std    6.858961e+05  1.084698e+06  6.106639e+05  2.484878e+07  2.561795e+07
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 75%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# max    1.100000e+08  1.100000e+08  1.100000e+08  1.200000e+08  1.200000e+08
#
#            Idle Min  binary_label
# count  2.520590e+06  2.520590e+06
# mean   8.893113e+06  1.688866e-01
# std    2.458208e+07  3.746518e-01
# min    0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00
# 50%    0.000000e+00  0.000000e+00
# 75%    0.000000e+00  0.000000e+00
# max    1.200000e+08  1.000000e+00
#
# [8 rows x 53 columns]

# %%
print('Applying SMOTE to training set only...')
smote = SMOTE(random_state=SEED, k_neighbors=5)
X_train_bal, y_train_bal = smote.fit_resample(X_train, y_train)
print(f'Before SMOTE: Normal={( y_train==0).sum():,}  Attack={(y_train==1).sum():,}')
print(f'After  SMOTE: Normal={(y_train_bal==0).sum():,}  Attack={(y_train_bal==1).sum():,}')
# Out:
# Applying SMOTE to training set only...
# Before SMOTE: Normal=1,467,264  Attack=298,156
# After  SMOTE: Normal=1,467,264  Attack=1,467,264

# %%
TIMESTEPS = 1

# Build a feature graph (adjacency) from balanced-train feature correlations
corr = np.corrcoef(X_train_bal, rowvar=False)
corr = np.nan_to_num(np.abs(corr), nan=0.0, posinf=0.0, neginf=0.0)
np.fill_diagonal(corr, 1.0)

# Keep top-k neighbors per feature to reduce noisy/weak edges
TOP_K = 8
idx = np.argsort(corr, axis=1)[:, -TOP_K:]
mask = np.zeros_like(corr)
rows = np.arange(corr.shape[0])[:, None]
mask[rows, idx] = 1.0
A = corr * mask
A = np.maximum(A, A.T)
np.fill_diagonal(A, 1.0)

# Symmetric normalization: A_hat = D^{-1/2} A D^{-1/2}
deg = A.sum(axis=1)
deg_inv_sqrt = np.power(deg + 1e-8, -0.5)
A_norm = (deg_inv_sqrt[:, None] * A) * deg_inv_sqrt[None, :]

X_train_lstm = X_train_bal.reshape(-1, TIMESTEPS, NUM_FEATURES)
X_val_lstm = X_val.reshape(-1, TIMESTEPS, NUM_FEATURES)
X_test_lstm = X_test.reshape(-1, TIMESTEPS, NUM_FEATURES)

print('GCN + BiGRU input shapes:')
print(f'  Train : {X_train_lstm.shape}')
print(f'  Val   : {X_val_lstm.shape}')
print(f'  Test  : {X_test_lstm.shape}')
print(f'  Features per timestep: {NUM_FEATURES}')
print(f'  Graph edges retained: {(A > 0).sum():,}')
# Out:
# GCN + BiGRU input shapes:
#   Train : (2934528, 1, 52)
#   Val   : (377081, 1, 52)
#   Test  : (378089, 1, 52)
#   Features per timestep: 52
#   Graph edges retained: 566

# %%
class SimpleGCN(tf.keras.layers.Layer):
    def __init__(self, units, adjacency, activation='relu', l2_reg=1e-3, **kwargs):
        super().__init__(**kwargs)
        self.units = units
        self.adjacency = tf.constant(adjacency, dtype=tf.float32)
        self.activation = tf.keras.activations.get(activation)
        self.l2_reg = l2_reg

    def build(self, input_shape):
        in_dim = int(input_shape[-1])
        self.kernel = self.add_weight(
            name='kernel',
            shape=(in_dim, self.units),
            initializer='glorot_uniform',
            regularizer=l2(self.l2_reg),
            trainable=True,
        )
        self.bias = self.add_weight(
            name='bias',
            shape=(self.units,),
            initializer='zeros',
            trainable=True,
        )

    def call(self, inputs):
        # inputs: (batch, timesteps=1, features)
        x = tf.squeeze(inputs, axis=1)
        x = tf.matmul(x, self.adjacency)
        x = tf.matmul(x, self.kernel) + self.bias
        if self.activation is not None:
            x = self.activation(x)
        return tf.expand_dims(x, axis=1)


def build_gcn_bigru(num_features, adjacency, timesteps=1, dropout=0.3, reg=1e-3):
    model = Sequential(name='GCN_BiGRU_AnomalyIDS')
    model.add(Input(shape=(timesteps, num_features)))

    # GCN front-end before recurrent blocks
    model.add(SimpleGCN(num_features, adjacency=adjacency, activation='relu', l2_reg=reg, name='gcn_front'))

    # Block 1
    model.add(Bidirectional(GRU(128, return_sequences=True,
                                kernel_regularizer=l2(reg),
                                recurrent_regularizer=l2(reg))))
    model.add(BatchNormalization())
    model.add(Dropout(dropout))

    # Block 2
    model.add(Bidirectional(GRU(64, return_sequences=False,
                                kernel_regularizer=l2(reg))))
    model.add(BatchNormalization())
    model.add(Dropout(dropout))

    # Dense head
    model.add(Dense(64, activation='relu', kernel_regularizer=l2(reg)))
    model.add(BatchNormalization())
    model.add(Dropout(dropout / 2))

    model.add(Dense(32, activation='relu'))
    model.add(Dropout(dropout / 2))

    # Output
    model.add(Dense(1, activation='sigmoid', name='anomaly_output'))
    return model


model = build_gcn_bigru(NUM_FEATURES, A_norm, TIMESTEPS)
model.summary()
# Out:
# WARNING:tensorflow:From c:\Users\ashis\.conda\envs\tf9\lib\site-packages\keras\src\backend\tensorflow\core.py:232: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# Model: "GCN_BiGRU_AnomalyIDS"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gcn_front (SimpleGCN)           │ (None, 1, 52)          │         2,756 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_2 (Bidirectional) │ (None, 1, 256)         │       139,776 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 1, 256)         │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 1, 256)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_3 (Bidirectional) │ (None, 128)            │       123,648 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ anomaly_output (Dense)          │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 278,341 (1.06 MB)
#  Trainable params: 277,445 (1.06 MB)
#  Non-trainable params: 896 (3.50 KB)

# %%
model.compile(
    optimizer=Adam(learning_rate=1e-3),
    loss='binary_crossentropy',
    metrics=[
        'accuracy',
        tf.keras.metrics.AUC(name='auc'),
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
)
print('✅ Model compiled!')
# Out:
# ✅ Model compiled!

# %%
# Class weights — extra guard against any residual imbalance
cw = compute_class_weight('balanced', classes=np.unique(y_train_bal), y=y_train_bal)
CLASS_WEIGHTS = dict(enumerate(cw))
print(f'Class weights: {CLASS_WEIGHTS}')
# Out:
# Class weights: {0: np.float64(1.0), 1: np.float64(1.0)}

# %%
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# PHASE 1 — Initial Training  (LR = 1e-3)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
print('🚀 PHASE 1 — Initial Training')
print('='*50)

cb1 = [
    EarlyStopping(monitor='val_auc', patience=10,
                  restore_best_weights=True, mode='max', verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5,
                      min_lr=1e-6, verbose=1),
    ModelCheckpoint('/kaggle/working/best_phase1.weights.h5',
                    monitor='val_auc', save_best_only=True, mode='max',
                    save_weights_only=True, verbose=1)
]

h1 = model.fit(
    X_train_lstm, y_train_bal,
    validation_data=(X_val_lstm, y_val),
    epochs=50,
    batch_size=512,
    class_weight=CLASS_WEIGHTS,
    callbacks=cb1,
    verbose=1
)
print('\n✅ Phase 1 complete!')
# Out:
# 🚀 PHASE 1 — Initial Training
# ==================================================
# Epoch 1/50
# 5730/5732 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9654 - auc: 0.9958 - loss: 0.0977 - precision: 0.9482 - recall: 0.9845
# Epoch 1: val_auc improved from -inf to 0.99328, saving model to /kaggle/working/best_phase1.weights.h5
# 5732/5732 ━━━━━━━━━━━━━━━━━━━━ 111s 19ms/step - accuracy: 0.9654 - auc: 0.9958 - loss: 0.0977 - precision: 0.9482 - recall: 0.9845 - val_accuracy: 0.9475 - val_auc: 0.9933 - val_loss: 0.0907 - val_precision: 0.7909 - val_recall: 0.9364 - learning_rate: 0.0010
# Epoch 2/50
# 5732/5732 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9675 - auc: 0.9962 - loss: 0.0890 - precision: 0.9505 - recall: 0.9864
# Epoch 2: val_auc improved from 0.99328 to 0.99741, saving model to /kaggle/working/best_phase1.weights.h5
# 5732/5732 ━━━━━━━━━━━━━━━━━━━━ 110s 19ms/step - accuracy: 0.9675 - auc: 0.9962 - loss: 0.0890 - precision: 0.9505 - recall: 0.9864 - val_accuracy: 0.9580 - val_auc: 0.9974 - val_loss: 0.0804 - val_precision: 0.8060 - val_recall: 0.9895 - learning_rate: 0.0010
# Epoch 3/50
# 5732/5732 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9686 - auc: 0.9965 - loss: 0.0847 - precision: 0.9518 - recall: 0.9872
# Epoch 3: val_auc did not improve from 0.99741
# 5732/5732 ━━━━━━━━━━━━━━━━━━━━ 110s 19ms/step - accuracy: 0.9686 - auc: 0.9965 - loss: 0.0847 - precision: 0.9518 - recall: 0.9872 - val_accuracy: 0.9610 - val_auc: 0.9963 - val_loss: 0.0742 - val_precision: 0.8329 - val_recall: 0.9618 - learning_rate: 0.0010
# Epoch 4/50
# 5730/5732 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9690 - auc: 0.9966 - loss: 0.0827 - precision: 0.9520 - recall: 0.9878
# Epoch 4: val_auc did not improve from 0.99741
# 5732/5732 ━━━━━━━━━━━━━━━━━━━━ 117s 20ms/step - accuracy: 0.9690 - auc: 0.9966 - loss: 0.0827 - precision: 0.9520 - recall: 0.9878 - val_accuracy: 0.9503 - val_auc: 0.9969 - val_loss: 0.0993 - val_precision: 0.7745 - val_recall: 0.9952 - learning_rate: 0.0010
# Epoch 5/50
# 5732/5732 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9691 - auc: 0.9966 - loss: 0.0825 - precision: 0.9521 - recall: 0.9879
# Epoch 5: val_auc did not improve from 0.99741
# 5732/5732 ━━━━━━━━━━━━━━━━━━━━ 117s 20ms/step - accuracy: 0.9691 - auc: 0.9966 - loss: 0.0825 - precision: 0.9521 - recall: 0.9879 - val_accuracy: 0.9587 - val_auc: 0.9960 - val_loss: 0.0860 - val_precision: 0.8153 - val_recall: 0.9770 - learning_rate: 0.0010
# Epoch 6/50
# 5732/5732 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9697 - auc: 0.9967 - loss: 0.0810 - precision: 0.9528 - recall: 0.9883
# Epoch 6: val_auc did not improve from 0.99741
# 5732/5732 ━━━━━━━━━━━━━━━━━━━━ 116s 20ms/step - accuracy: 0.9697 - auc: 0.9967 - loss: 0.0810 - precision: 0.9528 - recall: 0.9883 - val_accuracy: 0.9539 - val_auc: 0.9967 - val_loss: 0.0924 - val_precision: 0.7877 - val_recall: 0.9954 - learning_rate: 0.0010
# Epoch 7/50
# 5731/5732 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9699 - auc: 0.9967 - loss: 0.0807 - precision: 0.9534 - recall: 0.9880
# Epoch 7: val_auc did not improve from 0.99741
# 5732/5732 ━━━━━━━━━━━━━━━━━━━━ 117s 20ms/step - accuracy: 0.9699 - auc: 0.9967 - loss: 0.0807 - precision: 0.9534 - recall: 0.9880 - val_accuracy: 0.9517 - val_auc: 0.9968 - val_loss: 0.0943 - val_precision: 0.7807 - val_recall: 0.9930 - learning_rate: 0.0010
# Epoch 8/50
# 5731/5732 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9704 - auc: 0.9968 - loss: 0.0795 - precision: 0.9549 - recall: 0.9874
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 8: val_auc did not improve from 0.99741
# 5732/5732 ━━━━━━━━━━━━━━━━━━━━ 118s 21ms/step - accuracy: 0.9704 - auc: 0.9968 - loss: 0.0795 - precision: 0.9549 - recall: 0.9874 - val_accuracy: 0.9569 - val_auc: 0.9967 - val_loss: 0.0885 - val_precision: 0.8015 - val_recall: 0.9898 - learning_rate: 0.0010
# Epoch 9/50
# 5732/5732 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9733 - auc: 0.9972 - loss: 0.0727 - precision: 0.9602 - recall: 0.9874
# Epoch 9: val_auc improved from 0.99741 to 0.99759, saving model to /kaggle/working/best_phase1.weights.h5
# 5732/5732 ━━━━━━━━━━━━━━━━━━━━ 118s 21ms/step - accuracy: 0.9733 - auc: 0.9972 - loss: 0.0727 - precision: 0.9602 - recall: 0.9874 - val_accuracy: 0.9667 - val_auc: 0.9976 - val_loss: 0.0641 - val_precision: 0.8419 - val_recall: 0.9882 - learning_rate: 5.0000e-04
# Epoch 10/50
# 5732/5732 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9751 - auc: 0.9974 - loss: 0.0700 - precision: 0.9632 - recall: 0.9879
# Epoch 10: val_auc improved from 0.99759 to 0.99775, saving model to /kaggle/working/best_phase1.weights.h5
# 5732/5732 ━━━━━━━━━━━━━━━━━━━━ 118s 21ms/step - accuracy: 0.9751 - auc: 0.9974 - loss: 0.0700 - precision: 0.9632 - recall: 0.9879 - val_accuracy: 0.9712 - val_auc: 0.9978 - val_loss: 0.0659 - val_precision: 0.8613 - val_recall: 0.9890 - learning_rate: 5.0000e-04
# Epoch 11/50
# 5732/5732 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9760 - auc: 0.9974 - loss: 0.0688 - precision: 0.9646 - recall: 0.9883
# Epoch 11: val_auc did not improve from 0.99775
# 5732/5732 ━━━━━━━━━━━━━━━━━━━━ 117s 20ms/step - accuracy: 0.9760 - auc: 0.9974 - loss: 0.0688 - precision: 0.9646 - recall: 0.9883 - val_accuracy: 0.9585 - val_auc: 0.9977 - val_loss: 0.0859 - val_precision: 0.8045 - val_recall: 0.9965 - learning_rate: 5.0000e-04
# Epoch 12/50
# 5731/5732 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9767 - auc: 0.9975 - loss: 0.0681 - precision: 0.9653 - recall: 0.9889
# Epoch 12: val_auc did not improve from 0.99775
# 5732/5732 ━━━━━━━━━━━━━━━━━━━━ 117s 20ms/step - accuracy: 0.9767 - auc: 0.9975 - loss: 0.0681 - precision: 0.9653 - recall: 0.9889 - val_accuracy: 0.9678 - val_auc: 0.9977 - val_loss: 0.0795 - val_precision: 0.8423 - val_recall: 0.9954 - learning_rate: 5.0000e-04
# Epoch 13/50
# 5730/5732 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9773 - auc: 0.9975 - loss: 0.0671 - precision: 0.9659 - recall: 0.9895
# Epoch 13: val_auc did not improve from 0.99775
# 5732/5732 ━━━━━━━━━━━━━━━━━━━━ 117s 20ms/step - accuracy: 0.9773 - auc: 0.9975 - loss: 0.0671 - precision: 0.9659 - recall: 0.9895 - val_accuracy: 0.9634 - val_auc: 0.9974 - val_loss: 0.0783 - val_precision: 0.8330 - val_recall: 0.9797 - learning_rate: 5.0000e-04
# Epoch 14/50
# 5730/5732 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9776 - auc: 0.9976 - loss: 0.0668 - precision: 0.9663 - recall: 0.9896
# Epoch 14: val_auc improved from 0.99775 to 0.99794, saving model to /kaggle/working/best_phase1.weights.h5
# 5732/5732 ━━━━━━━━━━━━━━━━━━━━ 118s 21ms/step - accuracy: 0.9776 - auc: 0.9976 - loss: 0.0668 - precision: 0.9663 - recall: 0.9896 - val_accuracy: 0.9745 - val_auc: 0.9979 - val_loss: 0.0598 - val_precision: 0.8773 - val_recall: 0.9869 - learning_rate: 5.0000e-04
# Epoch 15/50
# 5731/5732 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9782 - auc: 0.9976 - loss: 0.0658 - precision: 0.9673 - recall: 0.9898
# Epoch 15: val_auc improved from 0.99794 to 0.99820, saving model to /kaggle/working/best_phase1.weights.h5
# 5732/5732 ━━━━━━━━━━━━━━━━━━━━ 119s 21ms/step - accuracy: 0.9782 - auc: 0.9976 - loss: 0.0658 - precision: 0.9673 - recall: 0.9898 - val_accuracy: 0.9736 - val_auc: 0.9982 - val_loss: 0.0617 - val_precision: 0.8679 - val_recall: 0.9952 - learning_rate: 5.0000e-04
# Epoch 16/50
# 5731/5732 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9783 - auc: 0.9976 - loss: 0.0658 - precision: 0.9675 - recall: 0.9899
# Epoch 16: val_auc did not improve from 0.99820
# 5732/5732 ━━━━━━━━━━━━━━━━━━━━ 119s 21ms/step - accuracy: 0.9783 - auc: 0.9976 - loss: 0.0658 - precision: 0.9675 - recall: 0.9899 - val_accuracy: 0.9727 - val_auc: 0.9975 - val_loss: 0.0658 - val_precision: 0.8664 - val_recall: 0.9909 - learning_rate: 5.0000e-04
# Epoch 17/50
# 5731/5732 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9781 - auc: 0.9976 - loss: 0.0661 - precision: 0.9668 - recall: 0.9901
# Epoch 17: val_auc did not improve from 0.99820
# 5732/5732 ━━━━━━━━━━━━━━━━━━━━ 119s 21ms/step - accuracy: 0.9781 - auc: 0.9976 - loss: 0.0661 - precision: 0.9668 - recall: 0.9901 - val_accuracy: 0.9569 - val_auc: 0.9973 - val_loss: 0.0861 - val_precision: 0.7987 - val_recall: 0.9957 - learning_rate: 5.0000e-04
# Epoch 18/50
# 5732/5732 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9786 - auc: 0.9977 - loss: 0.0652 - precision: 0.9678 - recall: 0.9901
# Epoch 18: val_auc did not improve from 0.99820
# 5732/5732 ━━━━━━━━━━━━━━━━━━━━ 119s 21ms/step - accuracy: 0.9786 - auc: 0.9977 - loss: 0.0652 - precision: 0.9678 - recall: 0.9901 - val_accuracy: 0.9543 - val_auc: 0.9978 - val_loss: 0.0846 - val_precision: 0.7886 - val_recall: 0.9967 - learning_rate: 5.0000e-04
# Epoch 19/50
# 5731/5732 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9783 - auc: 0.9976 - loss: 0.0659 - precision: 0.9673 - recall: 0.9900
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 19: val_auc did not improve from 0.99820
# 5732/5732 ━━━━━━━━━━━━━━━━━━━━ 119s 21ms/step - accuracy: 0.9783 - auc: 0.9976 - loss: 0.0659 - precision: 0.9673 - recall: 0.9900 - val_accuracy: 0.9713 - val_auc: 0.9981 - val_loss: 0.0696 - val_precision: 0.8577 - val_recall: 0.9952 - learning_rate: 5.0000e-04
# Epoch 20/50
# 5730/5732 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9805 - auc: 0.9980 - loss: 0.0600 - precision: 0.9706 - recall: 0.9911
# Epoch 20: val_auc improved from 0.99820 to 0.99824, saving model to /kaggle/working/best_phase1.weights.h5
# 5732/5732 ━━━━━━━━━━━━━━━━━━━━ 118s 21ms/step - accuracy: 0.9805 - auc: 0.9980 - loss: 0.0600 - precision: 0.9706 - recall: 0.9911 - val_accuracy: 0.9726 - val_auc: 0.9982 - val_loss: 0.0621 - val_precision: 0.8663 - val_recall: 0.9908 - learning_rate: 2.5000e-04
# Epoch 21/50
# 5731/5732 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9808 - auc: 0.9980 - loss: 0.0588 - precision: 0.9708 - recall: 0.9914
# Epoch 21: val_auc did not improve from 0.99824
# 5732/5732 ━━━━━━━━━━━━━━━━━━━━ 118s 21ms/step - accuracy: 0.9808 - auc: 0.9980 - loss: 0.0588 - precision: 0.9708 - recall: 0.9914 - val_accuracy: 0.9710 - val_auc: 0.9981 - val_loss: 0.0675 - val_precision: 0.8562 - val_recall: 0.9957 - learning_rate: 2.5000e-04
# Epoch 22/50
# 5732/5732 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9807 - auc: 0.9981 - loss: 0.0585 - precision: 0.9708 - recall: 0.9913
# Epoch 22: val_auc did not improve from 0.99824
# 5732/5732 ━━━━━━━━━━━━━━━━━━━━ 118s 21ms/step - accuracy: 0.9807 - auc: 0.9981 - loss: 0.0585 - precision: 0.9708 - recall: 0.9913 - val_accuracy: 0.9671 - val_auc: 0.9981 - val_loss: 0.0744 - val_precision: 0.8392 - val_recall: 0.9961 - learning_rate: 2.5000e-04
# Epoch 23/50
# 5731/5732 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9809 - auc: 0.9981 - loss: 0.0583 - precision: 0.9710 - recall: 0.9914
# Epoch 23: val_auc did not improve from 0.99824
# 5732/5732 ━━━━━━━━━━━━━━━━━━━━ 118s 21ms/step - accuracy: 0.9809 - auc: 0.9981 - loss: 0.0583 - precision: 0.9710 - recall: 0.9914 - val_accuracy: 0.9734 - val_auc: 0.9981 - val_loss: 0.0626 - val_precision: 0.8677 - val_recall: 0.9942 - learning_rate: 2.5000e-04
# Epoch 24/50
# 5730/5732 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9811 - auc: 0.9981 - loss: 0.0578 - precision: 0.9713 - recall: 0.9914
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 24: val_auc did not improve from 0.99824
# 5732/5732 ━━━━━━━━━━━━━━━━━━━━ 118s 21ms/step - accuracy: 0.9811 - auc: 0.9981 - loss: 0.0578 - precision: 0.9713 - recall: 0.9914 - val_accuracy: 0.9716 - val_auc: 0.9982 - val_loss: 0.0668 - val_precision: 0.8603 - val_recall: 0.9933 - learning_rate: 2.5000e-04
# Epoch 25/50
# 5732/5732 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9822 - auc: 0.9983 - loss: 0.0548 - precision: 0.9728 - recall: 0.9921
# Epoch 25: val_auc improved from 0.99824 to 0.99846, saving model to /kaggle/working/best_phase1.weights.h5
# 5732/5732 ━━━━━━━━━━━━━━━━━━━━ 119s 21ms/step - accuracy: 0.9822 - auc: 0.9983 - loss: 0.0548 - precision: 0.9728 - recall: 0.9921 - val_accuracy: 0.9766 - val_auc: 0.9985 - val_loss: 0.0578 - val_precision: 0.8809 - val_recall: 0.9959 - learning_rate: 1.2500e-04
# Epoch 26/50
# 5732/5732 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9823 - auc: 0.9983 - loss: 0.0539 - precision: 0.9730 - recall: 0.9922
# Epoch 26: val_auc improved from 0.99846 to 0.99850, saving model to /kaggle/working/best_phase1.weights.h5
# 5732/5732 ━━━━━━━━━━━━━━━━━━━━ 119s 21ms/step - accuracy: 0.9823 - auc: 0.9983 - loss: 0.0539 - precision: 0.9730 - recall: 0.9922 - val_accuracy: 0.9750 - val_auc: 0.9985 - val_loss: 0.0577 - val_precision: 0.8735 - val_recall: 0.9959 - learning_rate: 1.2500e-04
# Epoch 27/50
# 5731/5732 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9824 - auc: 0.9983 - loss: 0.0537 - precision: 0.9730 - recall: 0.9922
# Epoch 27: val_auc did not improve from 0.99850
# 5732/5732 ━━━━━━━━━━━━━━━━━━━━ 118s 21ms/step - accuracy: 0.9824 - auc: 0.9983 - loss: 0.0537 - precision: 0.9730 - recall: 0.9922 - val_accuracy: 0.9755 - val_auc: 0.9985 - val_loss: 0.0560 - val_precision: 0.8767 - val_recall: 0.9949 - learning_rate: 1.2500e-04
# Epoch 28/50
# 5730/5732 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9824 - auc: 0.9983 - loss: 0.0534 - precision: 0.9731 - recall: 0.9923
# Epoch 28: val_auc did not improve from 0.99850
# 5732/5732 ━━━━━━━━━━━━━━━━━━━━ 119s 21ms/step - accuracy: 0.9824 - auc: 0.9983 - loss: 0.0534 - precision: 0.9731 - recall: 0.9923 - val_accuracy: 0.9772 - val_auc: 0.9984 - val_loss: 0.0519 - val_precision: 0.8889 - val_recall: 0.9885 - learning_rate: 1.2500e-04
# Epoch 29/50
# 5731/5732 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9825 - auc: 0.9983 - loss: 0.0533 - precision: 0.9732 - recall: 0.9922
# Epoch 29: val_auc improved from 0.99850 to 0.99850, saving model to /kaggle/working/best_phase1.weights.h5
# 5732/5732 ━━━━━━━━━━━━━━━━━━━━ 119s 21ms/step - accuracy: 0.9825 - auc: 0.9983 - loss: 0.0533 - precision: 0.9732 - recall: 0.9922 - val_accuracy: 0.9764 - val_auc: 0.9985 - val_loss: 0.0536 - val_precision: 0.8824 - val_recall: 0.9923 - learning_rate: 1.2500e-04
# Epoch 30/50
# 5732/5732 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9826 - auc: 0.9983 - loss: 0.0529 - precision: 0.9733 - recall: 0.9925
# Epoch 30: val_auc improved from 0.99850 to 0.99855, saving model to /kaggle/working/best_phase1.weights.h5
# 5732/5732 ━━━━━━━━━━━━━━━━━━━━ 120s 21ms/step - accuracy: 0.9826 - auc: 0.9983 - loss: 0.0529 - precision: 0.9733 - recall: 0.9925 - val_accuracy: 0.9763 - val_auc: 0.9985 - val_loss: 0.0580 - val_precision: 0.8795 - val_recall: 0.9962 - learning_rate: 1.2500e-04
# Epoch 31/50
# 5192/5732 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.9826 - auc: 0.9983 - loss: 0.0528 - precision: 0.9733 - recall: 0.9923

# %%
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# PHASE 2 — Fine-Tuning  (LR = 1e-4)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
print('🔧 PHASE 2 — Fine-Tuning')
print('='*50)

# Rebuild architecture and load best phase-1 weights
model = build_gcn_bigru(NUM_FEATURES, A_norm, TIMESTEPS)
model.load_weights('/kaggle/working/best_phase1.weights.h5')
model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='binary_crossentropy',
    metrics=[
        'accuracy',
        tf.keras.metrics.AUC(name='auc'),
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
)

cb2 = [
    EarlyStopping(monitor='val_auc', patience=8,
                  restore_best_weights=True, mode='max', verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.3, patience=4,
                      min_lr=1e-7, verbose=1),
    ModelCheckpoint('/kaggle/working/best_finetuned.weights.h5',
                    monitor='val_auc', save_best_only=True, mode='max',
                    save_weights_only=True, verbose=1)
]

h2 = model.fit(
    X_train_lstm, y_train_bal,
    validation_data=(X_val_lstm, y_val),
    epochs=30,
    batch_size=256,
    class_weight=CLASS_WEIGHTS,
    callbacks=cb2,
    verbose=1
)
print('\n✅ Phase 2 complete!')
# Out:
# 🔧 PHASE 2 — Fine-Tuning
# ==================================================
# Epoch 1/30
# 11459/11463 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9819 - auc: 0.9981 - loss: 0.0593 - precision: 0.9733 - recall: 0.9911
# Epoch 1: val_auc improved from -inf to 0.99887, saving model to /kaggle/working/best_finetuned.keras
# 11463/11463 ━━━━━━━━━━━━━━━━━━━━ 120s 10ms/step - accuracy: 0.9819 - auc: 0.9981 - loss: 0.0593 - precision: 0.9733 - recall: 0.9911 - val_accuracy: 0.9777 - val_auc: 0.9989 - val_loss: 0.0536 - val_precision: 0.8858 - val_recall: 0.9963 - learning_rate: 1.0000e-04
# Epoch 2/30
# 11463/11463 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9821 - auc: 0.9982 - loss: 0.0581 - precision: 0.9736 - recall: 0.9912
# Epoch 2: val_auc improved from 0.99887 to 0.99887, saving model to /kaggle/working/best_finetuned.keras
# 11463/11463 ━━━━━━━━━━━━━━━━━━━━ 107s 9ms/step - accuracy: 0.9821 - auc: 0.9982 - loss: 0.0581 - precision: 0.9736 - recall: 0.9912 - val_accuracy: 0.9780 - val_auc: 0.9989 - val_loss: 0.0526 - val_precision: 0.8874 - val_recall: 0.9961 - learning_rate: 1.0000e-04
# Epoch 3/30
# 11463/11463 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9823 - auc: 0.9982 - loss: 0.0579 - precision: 0.9736 - recall: 0.9914
# Epoch 3: val_auc improved from 0.99887 to 0.99888, saving model to /kaggle/working/best_finetuned.keras
# 11463/11463 ━━━━━━━━━━━━━━━━━━━━ 107s 9ms/step - accuracy: 0.9823 - auc: 0.9982 - loss: 0.0579 - precision: 0.9736 - recall: 0.9914 - val_accuracy: 0.9783 - val_auc: 0.9989 - val_loss: 0.0528 - val_precision: 0.8884 - val_recall: 0.9963 - learning_rate: 1.0000e-04
# Epoch 4/30
# 11459/11463 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9821 - auc: 0.9982 - loss: 0.0577 - precision: 0.9735 - recall: 0.9912
# Epoch 4: val_auc did not improve from 0.99888
# 11463/11463 ━━━━━━━━━━━━━━━━━━━━ 108s 9ms/step - accuracy: 0.9821 - auc: 0.9982 - loss: 0.0577 - precision: 0.9735 - recall: 0.9912 - val_accuracy: 0.9766 - val_auc: 0.9988 - val_loss: 0.0563 - val_precision: 0.8806 - val_recall: 0.9967 - learning_rate: 1.0000e-04
# Epoch 5/30
# 11463/11463 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9822 - auc: 0.9982 - loss: 0.0577 - precision: 0.9736 - recall: 0.9913
# Epoch 5: val_auc improved from 0.99888 to 0.99891, saving model to /kaggle/working/best_finetuned.keras
# 11463/11463 ━━━━━━━━━━━━━━━━━━━━ 110s 10ms/step - accuracy: 0.9822 - auc: 0.9982 - loss: 0.0577 - precision: 0.9736 - recall: 0.9913 - val_accuracy: 0.9795 - val_auc: 0.9989 - val_loss: 0.0510 - val_precision: 0.8942 - val_recall: 0.9966 - learning_rate: 1.0000e-04
# Epoch 6/30
# 11463/11463 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9822 - auc: 0.9982 - loss: 0.0575 - precision: 0.9736 - recall: 0.9912
# Epoch 6: val_auc did not improve from 0.99891
# 11463/11463 ━━━━━━━━━━━━━━━━━━━━ 119s 10ms/step - accuracy: 0.9822 - auc: 0.9982 - loss: 0.0575 - precision: 0.9736 - recall: 0.9912 - val_accuracy: 0.9758 - val_auc: 0.9987 - val_loss: 0.0579 - val_precision: 0.8769 - val_recall: 0.9966 - learning_rate: 1.0000e-04
# Epoch 7/30
# 11462/11463 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9823 - auc: 0.9982 - loss: 0.0574 - precision: 0.9737 - recall: 0.9913
# Epoch 7: val_auc did not improve from 0.99891
# 11463/11463 ━━━━━━━━━━━━━━━━━━━━ 130s 11ms/step - accuracy: 0.9823 - auc: 0.9982 - loss: 0.0574 - precision: 0.9737 - recall: 0.9913 - val_accuracy: 0.9784 - val_auc: 0.9988 - val_loss: 0.0523 - val_precision: 0.8891 - val_recall: 0.9962 - learning_rate: 1.0000e-04
# Epoch 8/30
# 11461/11463 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9823 - auc: 0.9982 - loss: 0.0573 - precision: 0.9737 - recall: 0.9914
# Epoch 8: val_auc did not improve from 0.99891
# 11463/11463 ━━━━━━━━━━━━━━━━━━━━ 132s 12ms/step - accuracy: 0.9823 - auc: 0.9982 - loss: 0.0573 - precision: 0.9737 - recall: 0.9914 - val_accuracy: 0.9789 - val_auc: 0.9988 - val_loss: 0.0527 - val_precision: 0.8920 - val_recall: 0.9954 - learning_rate: 1.0000e-04
# Epoch 9/30
# 11460/11463 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9824 - auc: 0.9982 - loss: 0.0571 - precision: 0.9739 - recall: 0.9913
# Epoch 9: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
#
# Epoch 9: val_auc did not improve from 0.99891
# 11463/11463 ━━━━━━━━━━━━━━━━━━━━ 136s 12ms/step - accuracy: 0.9824 - auc: 0.9982 - loss: 0.0571 - precision: 0.9739 - recall: 0.9913 - val_accuracy: 0.9772 - val_auc: 0.9989 - val_loss: 0.0547 - val_precision: 0.8832 - val_recall: 0.9968 - learning_rate: 1.0000e-04
# Epoch 10/30
# 11463/11463 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9831 - auc: 0.9983 - loss: 0.0551 - precision: 0.9745 - recall: 0.9921
# Epoch 10: val_auc did not improve from 0.99891
# 11463/11463 ━━━━━━━━━━━━━━━━━━━━ 139s 12ms/step - accuracy: 0.9831 - auc: 0.9983 - loss: 0.0551 - precision: 0.9745 - recall: 0.9921 - val_accuracy: 0.9798 - val_auc: 0.9989 - val_loss: 0.0502 - val_precision: 0.8958 - val_recall: 0.9965 - learning_rate: 3.0000e-05
# Epoch 11/30
# 11461/11463 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9833 - auc: 0.9984 - loss: 0.0541 - precision: 0.9750 - recall: 0.9921
# Epoch 11: val_auc did not improve from 0.99891
# 11463/11463 ━━━━━━━━━━━━━━━━━━━━ 143s 12ms/step - accuracy: 0.9833 - auc: 0.9984 - loss: 0.0541 - precision: 0.9750 - recall: 0.9921 - val_accuracy: 0.9793 - val_auc: 0.9989 - val_loss: 0.0500 - val_precision: 0.8933 - val_recall: 0.9965 - learning_rate: 3.0000e-05
# Epoch 12/30
# 11462/11463 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9833 - auc: 0.9984 - loss: 0.0540 - precision: 0.9749 - recall: 0.9921
# Epoch 12: val_auc improved from 0.99891 to 0.99895, saving model to /kaggle/working/best_finetuned.keras
# 11463/11463 ━━━━━━━━━━━━━━━━━━━━ 149s 13ms/step - accuracy: 0.9833 - auc: 0.9984 - loss: 0.0540 - precision: 0.9749 - recall: 0.9921 - val_accuracy: 0.9796 - val_auc: 0.9990 - val_loss: 0.0495 - val_precision: 0.8944 - val_recall: 0.9967 - learning_rate: 3.0000e-05
# Epoch 13/30
# 11463/11463 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9834 - auc: 0.9984 - loss: 0.0535 - precision: 0.9751 - recall: 0.9921
# Epoch 13: val_auc did not improve from 0.99895
# 11463/11463 ━━━━━━━━━━━━━━━━━━━━ 155s 14ms/step - accuracy: 0.9834 - auc: 0.9984 - loss: 0.0535 - precision: 0.9751 - recall: 0.9921 - val_accuracy: 0.9799 - val_auc: 0.9989 - val_loss: 0.0494 - val_precision: 0.8963 - val_recall: 0.9964 - learning_rate: 3.0000e-05
# Epoch 14/30
# 11463/11463 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9834 - auc: 0.9984 - loss: 0.0534 - precision: 0.9750 - recall: 0.9922
# Epoch 14: val_auc did not improve from 0.99895
# 11463/11463 ━━━━━━━━━━━━━━━━━━━━ 160s 14ms/step - accuracy: 0.9834 - auc: 0.9984 - loss: 0.0534 - precision: 0.9750 - recall: 0.9922 - val_accuracy: 0.9799 - val_auc: 0.9989 - val_loss: 0.0497 - val_precision: 0.8961 - val_recall: 0.9967 - learning_rate: 3.0000e-05
# Epoch 15/30
# 11463/11463 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9833 - auc: 0.9984 - loss: 0.0535 - precision: 0.9749 - recall: 0.9921
# Epoch 15: val_auc did not improve from 0.99895
# 11463/11463 ━━━━━━━━━━━━━━━━━━━━ 164s 14ms/step - accuracy: 0.9833 - auc: 0.9984 - loss: 0.0535 - precision: 0.9749 - recall: 0.9921 - val_accuracy: 0.9799 - val_auc: 0.9989 - val_loss: 0.0490 - val_precision: 0.8959 - val_recall: 0.9969 - learning_rate: 3.0000e-05
# Epoch 16/30
# 11463/11463 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9834 - auc: 0.9984 - loss: 0.0533 - precision: 0.9750 - recall: 0.9922
# Epoch 16: val_auc did not improve from 0.99895
# 11463/11463 ━━━━━━━━━━━━━━━━━━━━ 167s 15ms/step - accuracy: 0.9834 - auc: 0.9984 - loss: 0.0533 - precision: 0.9750 - recall: 0.9922 - val_accuracy: 0.9796 - val_auc: 0.9989 - val_loss: 0.0498 - val_precision: 0.8945 - val_recall: 0.9966 - learning_rate: 3.0000e-05
# Epoch 17/30
# 11462/11463 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9834 - auc: 0.9984 - loss: 0.0531 - precision: 0.9750 - recall: 0.9921
# Epoch 17: val_auc improved from 0.99895 to 0.99898, saving model to /kaggle/working/best_finetuned.keras
# 11463/11463 ━━━━━━━━━━━━━━━━━━━━ 171s 15ms/step - accuracy: 0.9834 - auc: 0.9984 - loss: 0.0531 - precision: 0.9750 - recall: 0.9921 - val_accuracy: 0.9788 - val_auc: 0.9990 - val_loss: 0.0495 - val_precision: 0.8906 - val_recall: 0.9969 - learning_rate: 3.0000e-05
# Epoch 18/30
# 11461/11463 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9834 - auc: 0.9984 - loss: 0.0532 - precision: 0.9750 - recall: 0.9922
# Epoch 18: val_auc did not improve from 0.99898
# 11463/11463 ━━━━━━━━━━━━━━━━━━━━ 177s 15ms/step - accuracy: 0.9834 - auc: 0.9984 - loss: 0.0532 - precision: 0.9750 - recall: 0.9922 - val_accuracy: 0.9792 - val_auc: 0.9989 - val_loss: 0.0496 - val_precision: 0.8923 - val_recall: 0.9969 - learning_rate: 3.0000e-05
# Epoch 19/30
# 11461/11463 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9834 - auc: 0.9984 - loss: 0.0529 - precision: 0.9751 - recall: 0.9920
# Epoch 19: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
#
# Epoch 19: val_auc did not improve from 0.99898
# 11463/11463 ━━━━━━━━━━━━━━━━━━━━ 183s 16ms/step - accuracy: 0.9834 - auc: 0.9984 - loss: 0.0529 - precision: 0.9751 - recall: 0.9920 - val_accuracy: 0.9790 - val_auc: 0.9989 - val_loss: 0.0495 - val_precision: 0.8916 - val_recall: 0.9967 - learning_rate: 3.0000e-05
# Epoch 20/30
# 11460/11463 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9836 - auc: 0.9984 - loss: 0.0523 - precision: 0.9752 - recall: 0.9924
# Epoch 20: val_auc did not improve from 0.99898
# 11463/11463 ━━━━━━━━━━━━━━━━━━━━ 186s 16ms/step - accuracy: 0.9836 - auc: 0.9984 - loss: 0.0523 - precision: 0.9752 - recall: 0.9924 - val_accuracy: 0.9793 - val_auc: 0.9989 - val_loss: 0.0492 - val_precision: 0.8931 - val_recall: 0.9967 - learning_rate: 9.0000e-06
# Epoch 21/30
# 11463/11463 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9838 - auc: 0.9984 - loss: 0.0520 - precision: 0.9755 - recall: 0.9924
# Epoch 21: val_auc did not improve from 0.99898
# 11463/11463 ━━━━━━━━━━━━━━━━━━━━ 190s 17ms/step - accuracy: 0.9838 - auc: 0.9984 - loss: 0.0520 - precision: 0.9755 - recall: 0.9924 - val_accuracy: 0.9800 - val_auc: 0.9990 - val_loss: 0.0483 - val_precision: 0.8965 - val_recall: 0.9967 - learning_rate: 9.0000e-06
# Epoch 22/30
# 11462/11463 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9836 - auc: 0.9985 - loss: 0.0520 - precision: 0.9753 - recall: 0.9923
# Epoch 22: val_auc did not improve from 0.99898
# 11463/11463 ━━━━━━━━━━━━━━━━━━━━ 199s 17ms/step - accuracy: 0.9836 - auc: 0.9985 - loss: 0.0520 - precision: 0.9753 - recall: 0.9923 - val_accuracy: 0.9794 - val_auc: 0.9990 - val_loss: 0.0489 - val_precision: 0.8934 - val_recall: 0.9970 - learning_rate: 9.0000e-06
# Epoch 23/30
# 11461/11463 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9839 - auc: 0.9985 - loss: 0.0519 - precision: 0.9756 - recall: 0.9926
# Epoch 23: val_auc did not improve from 0.99898
# 11463/11463 ━━━━━━━━━━━━━━━━━━━━ 210s 18ms/step - accuracy: 0.9839 - auc: 0.9985 - loss: 0.0519 - precision: 0.9756 - recall: 0.9926 - val_accuracy: 0.9800 - val_auc: 0.9990 - val_loss: 0.0483 - val_precision: 0.8965 - val_recall: 0.9968 - learning_rate: 9.0000e-06
# Epoch 24/30
# 11461/11463 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9838 - auc: 0.9984 - loss: 0.0519 - precision: 0.9755 - recall: 0.9925
# Epoch 24: val_auc did not improve from 0.99898
# 11463/11463 ━━━━━━━━━━━━━━━━━━━━ 212s 18ms/step - accuracy: 0.9838 - auc: 0.9984 - loss: 0.0519 - precision: 0.9755 - recall: 0.9925 - val_accuracy: 0.9802 - val_auc: 0.9990 - val_loss: 0.0485 - val_precision: 0.8972 - val_recall: 0.9968 - learning_rate: 9.0000e-06
# Epoch 25/30
# 11462/11463 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9838 - auc: 0.9985 - loss: 0.0517 - precision: 0.9757 - recall: 0.9924
# Epoch 25: ReduceLROnPlateau reducing learning rate to 2.6999998226528985e-06.
#
# Epoch 25: val_auc did not improve from 0.99898
# 11463/11463 ━━━━━━━━━━━━━━━━━━━━ 218s 19ms/step - accuracy: 0.9838 - auc: 0.9985 - loss: 0.0517 - precision: 0.9757 - recall: 0.9924 - val_accuracy: 0.9800 - val_auc: 0.9990 - val_loss: 0.0482 - val_precision: 0.8964 - val_recall: 0.9968 - learning_rate: 9.0000e-06
# Epoch 25: early stopping
# Restoring model weights from the end of the best epoch: 17.
#
# ✅ Phase 2 complete!

# %%
# Load best fine-tuned weights and predict on the held-out test set
best_model = build_gcn_bigru(NUM_FEATURES, A_norm, TIMESTEPS)
best_model.load_weights('/kaggle/working/best_finetuned.weights.h5')

y_prob = best_model.predict(X_test_lstm, batch_size=512, verbose=0).flatten()

# Optimal threshold via Youden's J  (maximises TPR - FPR)
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
opt_idx = np.argmax(tpr - fpr)
OPT_THRESHOLD = float(thresholds[opt_idx])
y_pred = (y_prob >= OPT_THRESHOLD).astype(int)

print(f'Optimal threshold (Youden J): {OPT_THRESHOLD:.4f}')
# Out:
# Optimal threshold (Youden J): 0.5599

# %%
acc = accuracy_score(y_test, y_pred)
auc = roc_auc_score(y_test, y_prob)
f1 = f1_score(y_test, y_pred)

print('=' * 50)
print('   GCN + BiGRU ANOMALY IDS  —  TEST RESULTS')
print('=' * 50)
print(f'  Accuracy  :  {acc * 100:.2f}%')
print(f'  AUC-ROC   :  {auc * 100:.2f}%')
print(f'  F1-Score  :  {f1 * 100:.2f}%')
print()
print(classification_report(y_test, y_pred, target_names=['Normal Traffic', 'Attack']))
# Out:
# ==================================================
#    BiGRU ANOMALY IDS  —  TEST RESULTS
# ==================================================
#   Accuracy  :  98.05%
#   AUC-ROC   :  99.91%
#   F1-Score  :  94.53%
#
#                 precision    recall  f1-score   support
#
# Normal Traffic       1.00      0.98      0.99    314235
#         Attack       0.90      1.00      0.95     63854
#
#       accuracy                           0.98    378089
#      macro avg       0.95      0.99      0.97    378089
#   weighted avg       0.98      0.98      0.98    378089

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))
fig.suptitle('GCN + BiGRU Anomaly IDS — Test Evaluation', fontsize=13, fontweight='bold')

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
cm_pct = cm.astype(float) / cm.sum(axis=1)[:, None] * 100
sns.heatmap(cm_pct, annot=True, fmt='.1f', cmap='Blues',
            xticklabels=['Normal Traffic', 'Attack'],
            yticklabels=['Normal Traffic', 'Attack'],
            ax=axes[0], linewidths=0.5, annot_kws={'size': 13})
axes[0].set_title('Confusion Matrix (%)', fontweight='bold')
axes[0].set_ylabel('True Label')
axes[0].set_xlabel('Predicted Label')

for i in range(2):
    for j in range(2):
        axes[0].text(j + 0.5, i + 0.72, f'n={cm[i, j]:,}',
                     ha='center', va='center', fontsize=9, color='dimgray')

# ROC Curve
axes[1].plot(fpr, tpr, color='#1565C0', lw=2.5, label=f'GCN+BiGRU  AUC={auc:.4f}')
axes[1].plot([0, 1], [0, 1], 'gray', lw=1, ls='--', label='Random baseline')
axes[1].scatter(fpr[opt_idx], tpr[opt_idx], s=120, color='red', zorder=5,
                label=f'Best threshold = {OPT_THRESHOLD:.3f}')
axes[1].set_title('ROC Curve', fontweight='bold')
axes[1].set_xlabel('False Positive Rate')
axes[1].set_ylabel('True Positive Rate')
axes[1].legend(loc='lower right')
axes[1].grid(alpha=0.3)

plt.tight_layout()
plt.savefig('/kaggle/working/evaluation.png', dpi=150)
plt.show()

# %%
# Attack-wise confusion matrix (detected vs missed)
attack_mask = y_type_test != BENIGN_STR
attack_true = y_type_test[attack_mask]
attack_pred_detected = np.where(y_pred[attack_mask] == 1, 'Detected Attack', 'Missed (Pred Normal)')

attack_cm = pd.crosstab(
    pd.Series(attack_true, name='Attack Type'),
    pd.Series(attack_pred_detected, name='Prediction')
)
for col in ['Detected Attack', 'Missed (Pred Normal)']:
    if col not in attack_cm.columns:
        attack_cm[col] = 0
attack_cm = attack_cm[['Detected Attack', 'Missed (Pred Normal)']]
attack_cm_pct = attack_cm.div(attack_cm.sum(axis=1), axis=0).fillna(0.0) * 100

plt.figure(figsize=(10, 5))
ax = sns.heatmap(attack_cm_pct, annot=True, fmt='.1f', cmap='YlGnBu',
                 linewidths=0.5, cbar_kws={'label': 'Percent within attack type'})
ax.set_title('Attack-Type Confusion Matrix (%)', fontweight='bold')
ax.set_xlabel('Prediction')
ax.set_ylabel('True Attack Type')

for i, attack_name in enumerate(attack_cm.index):
    for j, col in enumerate(attack_cm.columns):
        ax.text(j + 0.5, i + 0.75, f"n={int(attack_cm.loc[attack_name, col]):,}",
                ha='center', va='center', fontsize=8, color='dimgray')

plt.tight_layout()
plt.show()

print('\nAttack detection recall by type (%):')
attack_recall = (attack_cm['Detected Attack'] / attack_cm.sum(axis=1) * 100).sort_values(ascending=False)
print(attack_recall.round(2).to_string())
